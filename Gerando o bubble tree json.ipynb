# %%
import sqlalchemy as sa
import json
import colour
from sqlalchemy.orm import sessionmaker

# %%
engine = sa.create_engine('mysql+pymysql://proprietarios_wp:.cachorrosemdonomorredefom3.@localhost/vaimudar')

# %%
s = sessionmaker(bind=engine)()

# %%
grupo_query = 'select name from wp_terms where term_id = {}'
obras_grupos_query = 'select name, slug from wp_terms, wp_term_relationships where wp_term_relationships.term_taxonomy_id = wp_terms.term_id and wp_term_relationships.object_id = {}'
obras_meta = 'select * from wp_postmeta where post_id = {}'
obras_res = s.execute("select id, post_title from wp_posts where post_type ='obras'")

dobra = {}
cidades = {}
grupo_slug = {}

total = 0

for obra in obras_res:
    oid = obra[0]    
    dobra[oid] = {'title': obra[1]}
    
    obras_meta = 'select * from wp_postmeta where post_id = {}'
    r = s.execute(obras_meta.format(oid))
    
    for om in r.fetchall():
        if om[2] == 'cidade':
            if not cidades.has_key(om[3]):
                cidades[om[3]] = [dobra[oid]]
            else:
                cidades[om[3]] += [dobra[oid]]
                
        if om[2] == 'valor_previsto_transp':
            dobra[oid]['valor'] = om[3]
            total += float(dobra[oid]['valor'])
            
        # Pega os grupos economicos
        grupos_names = []
        
        r = s.execute(obras_grupos_query.format(oid))
        for gname in r.fetchall():
            grupos_names.append(gname[0])
            grupo_slug[gname[0]] = gname[1]
        
        dobra[oid]['grupos'] = grupos_names

# %%
dbubble = []

cidade_cor = {'São Paulo': '#749e54'
             ,'Brasília': '#77b4d1'
             ,'Salvador': '#c2436c'
             ,'Manaus': '#949494'
             ,'Rio de Janeiro': '#a6549c'
             ,'Cuiabá': '#f45b9f'
             ,'Fortaleza': '#dba112'
             ,'Natal': '#c1426b'
             ,'Porto Alegre': '#efb605'
             ,'Curitiba': '#15688a'
             ,'Recife': '#dd9ee3'
             ,'Belo Horizonte': '#77d1c5'
             }

def mkcolor(v, c=None):
    if not c:
        if v < 0.3:
            v = 0.3
        elif v > 0.6:
            v = 0.6

        return colour.Color(hsl=(1, 0.5, v)).hex
    else:
        if cidade_cor.has_key(c.decode('iso8859-1').encode('utf-8')):
            return cidade_cor[c.decode('iso8859-1').encode('utf-8')]
        else:
            return colour.Color(hsl=(1, 0.5, v)).hex


for c in [cid for cid in cidades.keys() if cid[0].isupper()]:
    cidade_total = sum([float(o['valor']) for o in cidades[c]])
    dbubble += [{'label': c
                ,'T': c
                ,'amount': cidade_total
                ,'color': mkcolor(cidade_total/total, c)
                ,'children': []}]
    print '\n',c
    for obra in cidades[c]:
        ngrupos = float(len(obra['grupos']))
        
        gs = []
        for g in obra['grupos']:
            if ngrupos > 1:
                gs += [{'label': g, 'slug': grupo_slug[g], 'amount': float(obra['valor'])/ngrupos}]
            else:
                gs += [{'label': g, 'slug': grupo_slug[g], 'amount': float(obra['valor'])}]

        if len(gs) == 1:
            gs += [{'label':'', 'amount':0, 'color':'#fff'}]
        
        dbubble[-1]['children'] += [{'label': obra['title']
                                    ,'amount': float(obra['valor'])
                                    ,'color': mkcolor(float(obra['valor'])/cidade_total)
                                    ,'children': gs}]
    
    if len(dbubble[-1]['children']):
        dbubble[-1]['children'] += [{'label':'', 'amount':0, 'color':'#fff'}]
# Out:
# S�o Paulo
#
# Bras�lia
#
# Salvador
#
# Manaus
#
# Rio de Janeiro
#
# Cuiab�
#
# Fortaleza
#
# Natal
#
# Porto Alegre
#
# Curitiba
#
# Recife
#
# Belo Horizonte

# %%
json.dumps(dbubble, ensure_ascii=False)
# Out:
# '[{"color": "#749e54", "amount": 820000000.0, "children": [{"color": "#c66", "amount": 820000000.0, "children": [{"amount": 820000000.0, "slug": "odebrecht", "label": "Odebrecht"}, {"color": "#fff", "amount": 0, "label": ""}], "label": "Constru\xe7\xe3o do Est\xe1dio do Corinthians"}, {"color": "#fff", "amount": 0, "label": ""}], "T": "S\xe3o Paulo", "label": "S\xe3o Paulo"}, {"color": "#77b4d1", "amount": 1447500000.0, "children": [{"color": "#c66", "amount": 1403300000.0, "children": [{"amount": 701650000.0, "slug": "andrade-gutierrez-sa", "label": "Andrade Gutierrez S/A"}, {"amount": 701650000.0, "slug": "via-engenharia", "label": "Via Engenharia"}], "label": "Reconstru\xe7\xe3o do Est\xe1dio Nacional de Bras\xedlia"}, {"color": "#732626", "amount": 44200000.0, "children": [{"amount": 14733333.333333334, "slug": "trier", "label": "Trier"}, {"amount": 14733333.333333334, "slug": "geosonda", "label": "Geosonda"}, {"amount": 14733333.333333334, "slug": "iqs", "label": "IQS"}], "label": "DF-047"}, {"color": "#fff", "amount": 0, "label": ""}], "T": "Bras\xedlia", "label": "Bras\xedlia"}, {"color": "#c2436c", "amount": 689400000.0, "children": [{"color": "#c66", "amount": 689400000.0, "children": [{"amount": 344700000.0, "slug": "oas", "label": "Oas"}, {"amount": 344700000.0, "slug": "odebrecht", "label": "Odebrecht"}], "label": "Reconstru\xe7\xe3o do Est\xe1dio Fonte Nova"}, {"color": "#fff", "amount": 0, "label": ""}], "T": "Salvador", "label": "Salvador"}, {"color": "#949494", "amount": 669500000.0, "children": [{"color": "#c66", "amount": 669500000.0, "children": [{"amount": 669500000.0, "slug": "andrade-gutierrez-sa", "label": "Andrade Gutierrez S/A"}, {"color": "#fff", "amount": 0, "label": ""}], "label": "Reconstru\xe7\xe3o da Arena da Amaz\xf4nia"}, {"color": "#fff", "amount": 0, "label": ""}], "T": "Manaus", "label": "Manaus"}, {"color": "#a6549c", "amount": 2632200000.0, "children": [{"color": "#c66", "amount": 1582200000.0, "children": [{"amount": 263700000.0, "slug": "andrade-gutierrez-sa", "label": "Andrade Gutierrez S/A"}, {"amount": 263700000.0, "slug": "delta", "label": "Delta"}, {"amount": 263700000.0, "slug": "oas", "label": "Oas"}, {"amount": 263700000.0, "slug": "concremat", "label": "Concremat"}, {"amount": 263700000.0, "slug": "lider", "label": "L\xedder"}, {"amount": 263700000.0, "slug": "carioca-christiani-nielsen", "label": "Carioca Christiani Nielsen"}], "label": "BRT Transcarioca (Aeroporto / Penha / Barra)"}, {"color": "#933", "amount": 1050000000.0, "children": [{"amount": 350000000.0, "slug": "andrade-gutierrez-sa", "label": "Andrade Gutierrez S/A"}, {"amount": 350000000.0, "slug": "delta", "label": "Delta"}, {"amount": 350000000.0, "slug": "odebrecht", "label": "Odebrecht"}], "label": "Reforma do est\xe1dio M\xe1rio Filho (Maracan\xe3)"}, {"color": "#fff", "amount": 0, "label": ""}], "T": "Rio de Janeiro", "label": "Rio de Janeiro"}, {"color": "#f45b9f", "amount": 1623600000.0, "children": [{"color": "#c66", "amount": 1577600000.0, "children": [{"amount": 315520000.0, "slug": "caf", "label": "Caf"}, {"amount": 315520000.0, "slug": "cr-almeida", "label": "Cr Almeida"}, {"amount": 315520000.0, "slug": "magna", "label": "Magna"}, {"amount": 315520000.0, "slug": "santa-barbara", "label": "Santa Barbara"}, {"amount": 315520000.0, "slug": "astep", "label": "Astep"}], "label": "VLT Cuiab\xe1 / V\xe1rzea Grande"}, {"color": "#732626", "amount": 46000000.0, "children": [{"amount": 15333333.333333334, "slug": "agrimat", "label": "Agrimat"}, {"amount": 15333333.333333334, "slug": "atrativa", "label": "Atrativa"}, {"amount": 15333333.333333334, "slug": "ster", "label": "Ster"}], "label": "Corredor M\xe1rio Andreazza"}, {"color": "#fff", "amount": 0, "label": ""}], "T": "Cuiab\xe1", "label": "Cuiab\xe1"}, {"color": "#dba112", "amount": 1093774400.0, "children": [{"color": "#732626", "amount": 38219400.0, "children": [{"amount": 12739800.0, "slug": "convap", "label": "Convap"}, {"amount": 12739800.0, "slug": "pet ...

# %%
lk
# Out:
# '#d98c8c'

# %%
dbubble
# Out:
# [{'amount': 820000000.0,
#   'children': [{'amount': 820000000.0,
#     'children': [{'label': 'Odebrecht'}],
#     'label': 'Constru\xe7\xe3o do Est\xe1dio do Corinthians'}],
#   'color': '#150707',
#   'label': 'S\xe3o Paulo'},
#  {'amount': 1447500000.0,
#   'children': [{'amount': 1403300000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'},
#      {'label': 'Via Engenharia'}],
#     'label': 'Reconstru\xe7\xe3o do Est\xe1dio Nacional de Bras\xedlia'},
#    {'amount': 44200000.0,
#     'children': [{'label': 'Trier'}, {'label': 'Geosonda'}, {'label': 'IQS'}],
#     'label': 'DF-047'}],
#   'color': '#250c0c',
#   'label': 'Bras\xedlia'},
#  {'amount': 689400000.0,
#   'children': [{'amount': 689400000.0,
#     'children': [{'label': 'Oas'}, {'label': 'Odebrecht'}],
#     'label': 'Reconstru\xe7\xe3o do Est\xe1dio Fonte Nova'}],
#   'color': '#120606',
#   'label': 'Salvador'},
#  {'amount': 669500000.0,
#   'children': [{'amount': 669500000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'}],
#     'label': 'Reconstru\xe7\xe3o da Arena da Amaz\xf4nia'}],
#   'color': '#110606',
#   'label': 'Manaus'},
#  {'amount': 2632200000.0,
#   'children': [{'amount': 1582200000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'},
#      {'label': 'Delta'},
#      {'label': 'Oas'},
#      {'label': 'Concremat'},
#      {'label': 'L\xedder'},
#      {'label': 'Carioca Christiani Nielsen'}],
#     'label': 'BRT Transcarioca (Aeroporto / Penha / Barra)'},
#    {'amount': 1050000000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'},
#      {'label': 'Delta'},
#      {'label': 'Odebrecht'}],
#     'label': 'Reforma do est\xe1dio M\xe1rio Filho (Maracan\xe3)'}],
#   'color': '#441717',
#   'label': 'Rio de Janeiro'},
#  {'amount': 1623600000.0,
#   'children': [{'amount': 1577600000.0,
#     'children': [{'label': 'Caf'},
#      {'label': 'Cr Almeida'},
#      {'label': 'Magna'},
#      {'label': 'Santa Barbara'},
#      {'label': 'Astep'}],
#     'label': 'VLT Cuiab\xe1 / V\xe1rzea Grande'},
#    {'amount': 46000000.0,
#     'children': [{'label': 'Agrimat'},
#      {'label': 'Atrativa'},
#      {'label': 'Ster'}],
#     'label': 'Corredor M\xe1rio Andreazza'}],
#   'color': '#2a0e0e',
#   'label': 'Cuiab\xe1'},
#  {'amount': 1093774400.0,
#   'children': [{'amount': 38219400.0,
#     'children': [{'label': 'Convap'},
#      {'label': 'Petra'},
#      {'label': 'MWH BRASIL'}],
#     'label': 'Esta\xe7\xf5es: Padre C\xedcero e Juscelino Kubitscheck'},
#    {'amount': 518606000.0,
#     'children': [{'label': 'Queiroz Galv\xe3o S.A.'},
#      {'label': 'Andrade Mendonca'},
#      {'label': 'BWA'}],
#     'label': 'Reforma do Est\xe1dio Governador Pl\xe1cido Castelo (castel\xe3o)'},
#    {'amount': 33700000.0,
#     'children': [{'label': 'Soares Penido Obras, Constru\xe7\xf5es e Investimentos Ltda'},
#      {'label': 'Delta'}],
#     'label': 'BRT Av. Alberto Craveiro'},
#    {'amount': 151600000.0,
#     'children': [{'label': 'Soares Penido Obras, Constru\xe7\xf5es e Investimentos Ltda'},
#      {'label': 'Delta'}],
#     'label': 'Eixo Via Expressa/Raul Barbosa'},
#    {'amount': 34600000.0,
#     'children': [{'label': 'Soares Penido Obras, Constru\xe7\xf5es e Investimentos Ltda'},
#      {'label': 'Delta'}],
#     'label': 'BRT Av. Paulino Rocha'},
#    {'amount': 41600000.0,
#     'children': [{'label': 'Soares Penido Obras, Constru\xe7\xf5es e Investimentos Ltda'},
#      {'label': 'Delta'}],
#     'label': 'BRT Avenida Ded\xe9 Brasil'},
#    {'amount': 275449000.0,
#     'children': [{'label': 'Consbem'},
#      {'label': 'Engexata'},
#      {'label': 'Passarelli'},
#      {'label': 'MWH BRASIL'}],
#     'label': 'VLT: Parangaba/Mucuripe'}],
#   'color': '#1c0909',
#   'label': 'Fortaleza'},
#  {'amount': 872248000.0,
#   'children': [{'amount': 400000000.0,
#     'children': [{'label': 'Oas'}],
#     'label': 'Constru\xe7\xe3o da Arena das Dunas'},
#    {'amount': 28200000.0,
#     'children': [{'label': 'Im'}],
#     'label': 'Eixo 2: Implanta\xe7\xe3o da Via Prudente de Morais'},
#    {'amount': 73100000.0,
#     'children': [{'label': 'Eit'}],
#     'label': 'Acesso ao Novo Aeroporto de S\xe3o Gon\xe7alo do Amarante'},
#    {'amount': 370948000.0,
#     'children': [{'label': 'Queiroz Galv\xe3o S.A.'},
#      {'label': 'Eit'},
#      {'label': 'Galvao'},
#      {'label': 'Ferreira Guedes'}],
#     'label': 'Corredor Estruturante \x96 Zona Norte/Est\xe1dio Arena das Dunas'}],
#   'color': '#160707',
#   'label': 'Natal'},
#  {'amount': 330000000.0,
#   'children': [{'amount': 330000000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'}],
#     'label': 'Reforma do Est\xe1dio Beira Rio'}],
#   'color': '#080303',
#   'label': 'Porto Alegre'},
#  {'amount': 617400000.0,
#   'children': [{'amount': 326700000.0,
#     'children': [{'label': 'Engevix'}],
#     'label': 'Reforma e Amplia\xe7\xe3o do Complexo Esportivo Curitiba 2014'},
#    {'amount': 61600000.0,
#     'children': [{'label': 'Dataprom'},
#      {'label': 'Indra'},
#      {'label': 'Via 11'}],
#     'label': 'Sistema Integrado de Monitoramento'},
#    {'amount': 51500000.0,
#     'children': [{'label': 'Afirma'},
#      {'label': 'Cr Almeida'},
#      {'label': 'Dalcon'},
#      {'label': 'Esteio'}],
#     'label': 'Corredor Aeroporto / Rodoferrovi\xe1ria'},
#    {'amount': 12600000.0,
#     'children': [{'label': 'EMPO - Empresa Curitibana de Saneamento e Constru\xe7\xe3o Civil Ltda'}],
#     'label': 'Requalifica\xe7\xe3o do Terminal Santa C\xe2ndida (reforma e amplia\xe7\xe3o)'},
#    {'amount': 24200000.0,
#     'children': [{'label': 'Dalcon'},
#      {'label': 'Empo'},
#      {'label': 'EMPO - Empresa Curitibana de Saneamento e Constru\xe7\xe3o Civil Ltda'},
#      {'label': 'Sotil'},
#      {'label': 'Legnet'},
#      {'label': 'TERPASUL'},
#      {'label': 'Tramo'}],
#     'label': 'BRT: Extens\xe3o da Linha Verde Sul'},
#    {'amount': 53300000.0,
#     'children': [{'label': 'Dalcon'}, {'label': 'Unidec'}],
#     'label': 'Vias de Integra\xe7\xe3o Radial Metropolitanas'},
#    {'amount': 38600000.0,
#     'children': [{'label': 'Empo'},
#      {'label': 'Engefoto'},
#      {'label': 'Unidec'},
#      {'label': 'EMPO - Empresa Curitibana de Saneamento e Constru\xe7\xe3o Civil Ltda'},
#      {'label': 'Itauba'},
#      {'label': 'Roca'},
#      {'label': 'Mavillis'},
#      {'label': 'Venturi e Zen Ltda.'}],
#     'label': 'Requalifica\xe7\xe3o do Corredor Marechal Floriano'},
#    {'amount': 48900000.0,
#     'children': [{'label': 'Sial'},
#      {'label': 'URBS - Urbaniza\xe7\xe3o de Curitiba S.A.'},
#      {'label': 'O BETACEM'}],
#     'label': 'Requalifica\xe7\xe3o da Rodoferrovi\xe1ria (inclusive acessos)'}],
#   'color': '#100505',
#   'label': 'Curitiba'},
#  {'amount': 1390903000.0,
#   'children': [{'amount': 88100000.0,
#     'children': [{'label': 'MENDES JUNIOR ENGENHARIA SA'},
#      {'label': 'Servix'}],
#     'label': 'Corredor Caxang\xe1 (Leste/Oeste)'},
#    {'amount': 180900000.0,
#     'children': [{'label': 'Aterpa'}, {'label': 'Emsa'}],
#     'label': 'BRT: Norte / Sul - Trecho Igarassu / Tacaruna / Centro do Recife'},
#    {'amount': 137000000.0,
#     'children': [{'label': 'MENDES JUNIOR ENGENHARIA SA'},
#      {'label': 'Servix'}],
#     'label': 'BRT: Leste / Oeste - Ramal Cidade da Copa'},
#    {'amount': 433203000.0,
#     'children': [{'label': 'Queiroz Galv\xe3o S.A.'}, {'label': 'Galvao'}],
#     'label': 'Corredor da Via Mangue'},
#    {'amount': 19100000.0,
#     'children': [{'label': 'JAG Empreendimentos LTDA'}],
#     'label': 'Metr\xf4: Terminal Cosme e Dami\xe3o'},
#    {'amount': 532600000.0,
#     'children': [{'label': 'Odebrecht'}],
#     'label': 'Constru\xe7\xe3o da Arena Pernambuco'}],
#   'color': '#240c0c',
#   'label': 'Recife'},
#  {'amount': 2100600000.0,
#   'children': [{'amount': 695000000.0,
#     'children': [{'label': 'Construcap'},
#      {'label': 'Egesa'},
#      {'label': 'Hap'}],
#     'label': 'Reforma do Est\xe1dio Magalh\xe3es Pinto (mineir\xe3o)'},
#    {'amount': 713400000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'},
#      {'label': 'Barbosa Mello'},
#      {'label': 'Constran'},
#      {'label': 'Cowan'},
#      {'label': 'Delta'}],
#     'label': 'BRT: Ant\xf4nio Carlos / Pedro I'},
#    {'amount': 233900000.0,
#     'children': [{'label': 'Andrade Gutierrez S/A'},
#      {'label': 'MENDES JUNIOR ENGENHARIA SA'},
#      {'label': 'Via Engenharia'}],
#     'label': 'Boulevard Arrudas / Tereza Cristina'},
#    {'amount': 168500000.0,
#     'children': [{'label': 'Constran'}, {'label': 'Logit'}, {'label': 'UTC'}],
#     'label': 'Corredor Pedro II e Obras Complementares nos BRTs Antonio Carlos/Pedro I e Cristiano Machado'},
#    {'amount': 57400000.0,
#     'children': [{'label': 'Constran'}, {'label': 'Convap'}, {'label': 'UTC'}],
#     'label': 'BRT: Cristiano Machado'},
#    {'amount': 70500000.0,
#     'children': [{'label': 'Tratenge'}, {'label': 'Cetenco'}],
#     'label': 'BRT: \xc1rea Central'},
#    {'amount': 31600000.0,
#     'children': [{'label': 'Logann'},
#      {'label': 'Peltier'},
#      {'label': 'Sengel'},
#      {'label': 'Conectel'},
#      {'label': 'Montebelense'}],
#     'label': 'Expans\xe3o da Central de Controle de Tr\xe2nsito'},
#    {'amount': 130300000.0,
#     'children': [{'label': 'Convap'},
#      {'label': 'Cowan'},
#      {'label': 'Vict\xf3ria Tassara'}],
#     'label': 'Via 210 (Liga\xe7\xe3o Via Min\xe9rio / Tereza Cristina)'}],
#   'color': '#361212',
#   'label': 'Belo Horizonte'}]
